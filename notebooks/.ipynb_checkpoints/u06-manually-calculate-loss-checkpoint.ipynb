# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
X = [1,2,3]
Y = [1,2,3]

# %%
plt.plot(X, Y,marker = "o")

# %% [markdown]
# Our loss function, which we want to minimize is
#
# $J(\beta) = \frac{1}{2N} \sum^{N}_{i=1}{(Y_i - \beta X_i)^2}$
